# %% [markdown]
# ## Project Description
#
# This dataset utilizes data from 2014 Major League Baseball seasons in order to develop an algorithm that predicts the number of wins for a given team in the 2015 season based on several different indicators of success. There are 16 different features that will be used as the inputs to the machine learning and the output will be a value that represents the number of wins.
#
# ## Input features:
# 1.	W - This indicates the number of Wins credited to a pitcher: number of games where pitcher was pitching while their team took the lead and went on to win, also the starter needs to pitch at least 5 innings of work.
#
# 2.	R - This indicates Runs scored. A run is scored when a player advances around first, second and third base and returns safely to home plate, touching the bases in that order, before three outs are recorded and all obligations to reach base safely on batted balls are met or assured: number of times a player crosses home plate.
#
# 3.	AB - This means At bat or time at bat. It's is a batter's turn batting against a pitcher: plate appearances, not including bases on balls, being hit by pitch, sacrifices, interference, or obstruction.
#
# 4.	H - This means Hit. It's also called a "base hit", is credited to a batter when the batter safely reaches or passes first base after hitting the ball into fair territory, without the benefit of either an error or a fielder's choice: reaching base because of a batted, fair ball without error by the defense.
#
# 5.	2B - This means the act of a batter striking the pitched ball and safely reaching second base without being called out by the umpire, without the benefit of a fielder's misplay (see error) or another runner being put out on a fielder's choice. A double is a type of hit (the others being the single, triple and home run) and is sometimes called a "two-bagger" or "two-base hit": hits on which the batter reaches second base safely without the contribution of a fielding error.
#
# 6.	3B - This measns a Triple.It's is the act of a batter safely reaching third base after hitting the ball, with neither the benefit of a fielder's misplay nor another runner being put out on a fielder's choice. A triple is sometimes called a "three-bagger" or "three-base hit": hits on which the batter reaches third base safely without the contribution of a fielding error.
#
# 7.	HR - This means Home runs. It's scored when the ball is hit in such a way that the batter is able to circle the bases and reach home plate safely in one play without any errors being committed by the defensive team. A home run is usually achieved by hitting the ball over the outfield fence between the foul poles (or hitting either foul pole) without the ball touching the field: hits on which the batter successfully touched all four bases, without the contribution of a fielding error.
#
# 8.	BB - This means Base on balls (also called a "walk"). It occurs in baseball when a batter receives four pitches that the umpire calls balls, and is in turn awarded first base without the possibility of being called out: hitter not swinging at four pitches called out of the strike zone and awarded first base.
#
# 9.	SO - Also denoted as "K" means Strikeout. It occurs when a batter accumulates three strikes during a time at bat. It usually means that the batter is out: number of batters who received strike three.
#
# 10.	SB - This means Stolen base. It occurs when a runner advances to a base to which they are not entitled and the official scorer rules that the advance should be credited to the action of the runner: number of bases advanced by the runner while the ball is in the possession of the defense.
#
# 11.	RA - This means Run Average. It refer to measures of the rate at which runs are allowed or scored.
#
# 12.	ER - This means Earned run. It refers to any run that was fully enabled by the offensive team's production in the face of competent play from the defensive team: number of runs that did not occur as a result of errors or passed balls.
#
# 13.	ERA - This means Earned Run Average. It refers to the average of earned runs allowed by a pitcher per nine innings pitched (i.e. the traditional length of a game). It is determined by dividing the number of earned runs allowed by the number of innings pitched and multiplying by nine: total number of earned runs (see "ER" above), multiplied by 9, divided by innings pitched.
#
# 14.	CG - This means Complete Game. It's the act of a pitcher pitching an entire game without the benefit of a relief pitcher. A pitcher who meets this criterion will be credited with a complete game regardless of the number of innings played: number of games where player was the only pitcher for their team.
#
# 15.	SHO - This means Shutout. It refers to the act by which a single pitcher pitches a complete game and does not allow the opposing team to score a run: number of complete games pitched with no runs allowed.
#
# 16.	SV - This means Save. It's credited to a pitcher who finishes a game for the winning team under certain prescribed circumstances: number of games where the pitcher enters a game led by the pitcher's team, finishes the game without surrendering the lead, is not the winning pitcher, and either (a) the lead was three runs or fewer when the pitcher entered the game; (b) the potential tying run was on base, at bat, or on deck; or (c) the pitcher pitched three or more innings.
#
# 17.	E - This means Errors. It's an act, in the judgment of the official scorer, of a fielder misplaying a ball in a manner that allows a batter or baserunner to advance one or more bases or allows a plate appearance to continue after the batter should have been put out. The term error is sometimes used to refer to the play during which an error was committed: number of times a fielder fails to make a play he should have made with common effort, and the offense benefits as a result.
#
# ## Output:
# - Number of predicted wins (W)
#
# To understand the columns meaning, follow the link given below to understand the baseball statistics: https://en.wikipedia.org/wiki/Baseball_statistics
#
# For downloading the dataset, use the link given below.

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

# %%
# Setting style parameters for graphs
sns.set_style('darkgrid')
plt.rcParams['font.size']=15
plt.rcParams['figure.figsize']=(10,7)
#plt.rcParams['figure.facecolor']='#FFE5B4'

# %% [markdown]
# ## Data Exploration:

# %%
# Load Dataset

data=pd.read_csv(r"C:\Users\JPGD\Documents\ANDREA GOMEZ\FLIP ROBO TECHNOLOGIES INTERNSHIP\Projects\Evaluation Projects\Datasets\baseball.csv")
data.head(5)
# Out:
#     W    R    AB     H   2B  3B   HR   BB    SO   SB   RA   ER   ERA  CG  SHO  \
# 0  95  724  5575  1497  300  42  139  383   973  104  641  601  3.73   2    8
# 1  83  696  5467  1349  277  44  156  439  1264   70  700  653  4.07   2   12
# 2  81  669  5439  1395  303  29  141  533  1157   86  640  584  3.67  11   10
# 3  76  622  5533  1381  260  27  136  404  1231   68  701  643  3.98   7    9
# 4  74  689  5605  1515  289  49  151  455  1259   83  803  746  4.64   7   12
#
#    SV    E
# 0  56   88
# 1  45   86
# 2  38   79
# 3  37  101
# 4  35   86

# %%
# Checking the dimension of the dataset.

data.shape
# Out:
# (30, 17)

# %% [markdown]
# The dataset has 30 observations and 17 features, out of which W (Wins) is the target variable.

# %%
# Getting an overview of the dataset by checking it's information 
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30 entries, 0 to 29
# Data columns (total 17 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   W       30 non-null     int64
#  1   R       30 non-null     int64
#  2   AB      30 non-null     int64
#  3   H       30 non-null     int64
#  4   2B      30 non-null     int64
#  5   3B      30 non-null     int64
#  6   HR      30 non-null     int64
#  7   BB      30 non-null     int64
#  8   SO      30 non-null     int64
#  9   SB      30 non-null     int64
#  10  RA      30 non-null     int64
#  11  ER      30 non-null     int64
#  12  ERA     30 non-null     float64
#  13  CG      30 non-null     int64
#  14  SHO     30 non-null     int64
#  15  SV      30 non-null     int64
#  16  E       30 non-null     int64
# dtypes: float64(1), int64(16)
# memory usage: 4.1 KB

# %% [markdown]
# According to the dataset information, there are no missing values and most of the data values are integers, except for ERA (Earned Run Average) feature, which has float values. But overall, this dataset is made up of numerical data.

# %%
# Checkin missing values

data.isnull().sum()
# Out:
# W      0
# R      0
# AB     0
# H      0
# 2B     0
# 3B     0
# HR     0
# BB     0
# SO     0
# SB     0
# RA     0
# ER     0
# ERA    0
# CG     0
# SHO    0
# SV     0
# E      0
# dtype: int64

# %% [markdown]
# In this way I can confirm there are no missing data in the dataset.

# %% [markdown]
# ## Description of DataSet

# %%
# Data description - to get an overview of numerical data

round(data.describe(),2)
# Out:
#             W       R       AB        H      2B     3B      HR      BB  \
# count   30.00   30.00    30.00    30.00   30.00  30.00   30.00   30.00
# mean    80.97  688.23  5516.27  1403.53  274.73  31.30  163.63  469.10
# std     10.45   58.76    70.47    57.14   18.10  10.45   31.82   57.05
# min     63.00  573.00  5385.00  1324.00  236.00  13.00  100.00  375.00
# 25%     74.00  651.25  5464.00  1363.00  262.25  23.00  140.25  428.25
# 50%     81.00  689.00  5510.00  1382.50  275.50  31.00  158.50  473.00
# 75%     87.75  718.25  5570.00  1451.50  288.75  39.00  177.00  501.25
# max    100.00  891.00  5649.00  1515.00  308.00  49.00  232.00  570.00
#
#             SO      SB      RA      ER    ERA     CG    SHO     SV       E
# count    30.00   30.00   30.00   30.00  30.00  30.00  30.00  30.00   30.00
# mean   1248.20   83.50  688.23  635.83   3.96   3.47  11.30  43.07   94.33
# std     103.76   22.82   72.11   70.14   0.45   2.76   4.12   7.87   13.96
# ...

# %% [markdown]
# From the data description above I can see the following:
# - The count of all columns are the same, which confirms once again that there are no missing values in this dataset.
# - High std values in 13 out of 17 features (W,R,AB,H,2B,3B,HR,BB,SO,SB,RA,ER and E) show that the data points are spread out further from the mean.
# - However, the mean and the median values are close together in almost all features, indicating that there is a symmetrical distribution in most of the features. Overall, the distribution is not skewed too badly in all features.

# %%
# Checking duplicates

print("Total Duplicate Rows are:", data.duplicated().sum())
# Out:
# Total Duplicate Rows are: 0

# %% [markdown]
# There are no duplicates in the dataset.

# %% [markdown]
# ### Separate discrete and continuous numerical features

# %%
# Separating Numerical columns in the test dataset
# Discrete data
discreteData=[i for i in data.columns if ((data[i].dtypes!='float64'))]

# Checking the discrete columns
data[discreteData].head()
# Out:
#     W    R    AB     H   2B  3B   HR   BB    SO   SB   RA   ER  CG  SHO  SV  \
# 0  95  724  5575  1497  300  42  139  383   973  104  641  601   2    8  56
# 1  83  696  5467  1349  277  44  156  439  1264   70  700  653   2   12  45
# 2  81  669  5439  1395  303  29  141  533  1157   86  640  584  11   10  38
# 3  76  622  5533  1381  260  27  136  404  1231   68  701  643   7    9  37
# 4  74  689  5605  1515  289  49  151  455  1259   83  803  746   7   12  35
#
#      E
# 0   88
# 1   86
# 2   79
# 3  101
# 4   86

# %%
print(discreteData)
print("There are",len(discreteData),"discrete features in the dataset.")
# Out:
# ['W', 'R', 'AB', 'H', '2B', '3B', 'HR', 'BB', 'SO', 'SB', 'RA', 'ER', 'CG', 'SHO', 'SV', 'E']
# There are 16 discrete features in the dataset.

# %%
# Separating Numerical columns in the test dataset
# Continuous data

continuousData=[i for i in data.columns if((data[i].dtypes=='float64'))]
# Checking the continuous columns
data[continuousData].head()
# Out:
#     ERA
# 0  3.73
# 1  4.07
# 2  3.67
# 3  3.98
# 4  4.64

# %%
print(continuousData)
print("There is",len(continuousData),"continuous features in the dataset.")
# Out:
# ['ERA']
# There is 1 continuous features in the dataset.

# %% [markdown]
# ## Data Visualization

# %% [markdown]
# ### Numerical feature distribution

# %%
# Exploring the numerical features
# Plot univariate distribution of continuous data

plt.figure(figsize=(30,90),facecolor="white")
plotnumber=1

for i in continuousData:
    ax=plt.subplot(12,3,plotnumber)
    sns.distplot(data[i])
    plt.xlabel(i)
    plotnumber+=1
plt.show()

# %% [markdown]
# There is only one continuous feature, "ERA", and it looks normally distributed.

# %%
# Exploring the numerical features
# Plot univariate distribution of discrete data

plt.figure(figsize=(30,90),facecolor="white")
plotnumber=1

for i in discreteData:
    fig, ax1 = plt.subplots()
    ax2 = ax1.twinx()
    sns.distplot(data[i], kde=False, ax=ax1)
    sns.distplot(data[i], hist=False, ax=ax2, kde_kws={'bw':1})
    plt.xlabel(i)
    plotnumber+=1
plt.show()

# %% [markdown]
# Overall, we can see that the distribution in the 16 discrete features, is not skewed too badly in all features.
#
# Era feature looks normally distributed. In the data description, we can see that there is a slight difference between the median (4.03) and the mean (3.96) in this feature. There is also a slight difference between the median and the mean in features R,2B, 3B, SB and in the target feature "W".

# %% [markdown]
# ### Numerical features Vs. Target Variable

# %%
# Regplot (and lmplot have best fit line)
plt.figure(figsize=(20,25))
p=1
for i in data:
    if p<=20:
        plt.subplot(5,4,p)
        sns.regplot(x='W',y=i,data=data,color='m')
        plt.xlabel("W")
        plt.ylabel(i)
    p+=1

plt.show()

# %% [markdown]
# From this figure we can see that most of the features are no correlated to target variable. Except for R,HR,2B,BB which show a weak positive correlation; SHO and SV a moderate positive correlation, while RA, ER and ERA show a strong negative correlation.

# %% [markdown]
# https://ashishanand007.medium.com/baseball-case-study-7a30a94982cf

# %% [markdown]
# ## Outliers

# %%
# Check the outliers by plotting boxplot

plt.figure(figsize=(20,15),facecolor="white")
plotnumber=1
for col in data:
    if plotnumber<=8:
        ax=plt.subplot(3,3,plotnumber)
        sns.boxplot(data[col],palette="Set2_r")
        plt.xlabel(col,fontsize=15)
        plt.yticks(rotation=0,fontsize=10)
    plotnumber+=1
plt.tight_layout()

# %% [markdown]
# There are no outliers in the dataset. Except for R.

# %%
# Explore and Remove the outliers - R Feature

data.groupby('R',sort=True)['R'].count()
# Out:
# R
# 573    1
# 613    1
# 622    1
# 626    1
# 640    1
# 644    1
# 647    1
# 650    1
# 655    1
# 656    1
# 661    1
# 667    1
# 669    1
# 683    1
# 689    2
# 694    1
# 696    2
# 697    1
# 703    1
# 713    1
# 720    1
# 724    1
# 729    1
# 737    1
# 748    1
# 751    1
# 764    1
# 891    1
# Name: R, dtype: int64

# %% [markdown]
# We can see there is just one value with a difference of 127 number of times a player crosses home plate from the 75% percentile. Thus, I will remove it.

# %%
# Creating a new dataframe that excludes values greater than 764 in R feature.
data2=data[data['R']<=764]

# Checking that these values have been removed in the dataset
data2.groupby(['R'],sort=True)['R'].count()
# Out:
# R
# 573    1
# 613    1
# 622    1
# 626    1
# 640    1
# 644    1
# 647    1
# 650    1
# 655    1
# 656    1
# 661    1
# 667    1
# 669    1
# 683    1
# 689    2
# 694    1
# 696    2
# 697    1
# 703    1
# 713    1
# 720    1
# 724    1
# 729    1
# 737    1
# 748    1
# 751    1
# 764    1
# Name: R, dtype: int64

# %%
# Verify the outcome by using Zscore Method
from scipy.stats import zscore

out_features=data[data.columns]
z=np.abs(zscore(out_features))
z
# Out:
# array([[1.36540860e+00, 6.19077968e-01, 8.47731264e-01, 1.66368512e+00,
#         1.42017307e+00, 1.04119304e+00, 7.87298598e-01, 1.53490242e+00,
#         2.69762957e+00, 9.13883291e-01, 6.66233927e-01, 5.05110079e-01,
#         5.06955186e-01, 5.39806195e-01, 8.14628593e-01, 1.67160651e+00,
#         4.61469635e-01],
#        [1.97838300e-01, 1.34431656e-01, 7.11093535e-01, 9.70680764e-01,
#         1.27403389e-01, 1.23580856e+00, 2.43966683e-01, 5.36591904e-01,
#         1.54878442e-01, 6.01825582e-01, 1.65970766e-01, 2.48929848e-01,
#         2.54597523e-01, 5.39806195e-01, 1.72800005e-01, 2.49879323e-01,
#         6.07196888e-01],
#        [3.24325082e-03, 3.32905860e-01, 1.11523330e+00, 1.51891367e-01,
#         1.58879521e+00, 2.23807850e-01, 7.23377196e-01, 1.13914361e+00,
#         8.93981893e-01, 1.11449182e-01, 6.80339091e-01, 7.51623132e-01,
#         6.41346840e-01, 2.77264091e+00, 3.20914294e-01, 6.54856158e-01,
#         1.11724227e+00],
# ...

# %%
# Threshold=3
np.where(z>3)
# Out:
# (array([5], dtype=int64), array([1], dtype=int64))

# %%
data3=data[(z<3).all(axis=1)]
data3.shape
# Out:
# (29, 17)

# %%
data2.shape
# Out:
# (29, 17)

# %%
# Shape of Old and New DataFrame
print("Old DataFrame - ",data.shape[0])
print("New DataFrame - ",data2.shape[0])
print("New DataFrame Zscore Method - ",data2.shape[0])
# Out:
# Old DataFrame -  30
# New DataFrame -  29
# New DataFrame Zscore Method -  29

# %%
print("Data Loss Percentage - ",((data.shape[0]-data2.shape[0])/data.shape[0]*100))
print("Data Loss Percentage Zscore Method - ",((data.shape[0]-data3.shape[0])/data.shape[0]*100))
# Out:
# Data Loss Percentage -  3.3333333333333335
# Data Loss Percentage Zscore Method -  3.3333333333333335

# %% [markdown]
# Both methods show that there was only one outlier (3.33% loss) in Runs Scored "R" feature, which has been removed.

# %% [markdown]
# ## Correlation

# %%
## Explore the correlation between numerical features in train dataset
cor=data2.corr()
cor
# Out:
#             W         R        AB         H        2B        3B        HR  \
# W    1.000000  0.390451 -0.085780 -0.018360  0.384886 -0.206737  0.245697
# R    0.390451  1.000000  0.438022  0.433525  0.469293  0.134204  0.586894
# AB  -0.085780  0.438022  1.000000  0.769159  0.490752  0.445604 -0.064653
# H   -0.018360  0.433525  0.769159  1.000000  0.528016  0.582024 -0.218711
# 2B   0.384886  0.469293  0.490752  0.528016  1.000000  0.342419 -0.098695
# 3B  -0.206737  0.134204  0.445604  0.582024  0.342419  1.000000 -0.369299
# HR   0.245697  0.586894 -0.064653 -0.218711 -0.098695 -0.369299  1.000000
# BB   0.447513  0.258450 -0.137850 -0.222271  0.211243 -0.404852  0.336814
# SO   0.156469  0.081158 -0.111243 -0.371861 -0.096772 -0.196586  0.479914
# SB  -0.169503  0.075323  0.373674  0.417877  0.194308  0.483818 -0.166072
# RA  -0.823176 -0.013858  0.315499  0.244606 -0.215196  0.312750 -0.092586
# ER  -0.815308  0.007727  0.309146  0.280571 -0.224993  0.333731 -0.062094
# ...

# %% [markdown]
# The data shows the correlation between all features. We can visualize it by plotting a heatmap.

# %%
# Visualizing the correlation matrix by plotting heatmap
plt.figure(figsize=(18,10))
sns.heatmap(data2.corr(),linewidths=0.1,fmt=".1g",linecolor="black",annot=True,cmap="Blues_r")
plt.yticks(rotation=0);
plt.show()

# %% [markdown]
# From the data and the correlation graph above, it's possible to see the following:
#
# - There is a positive correlation between target variable and SV,SHO.
# - There is a negative correlation between target variable and ERA, ER and RA.
# - Several independent variables are highly correlated with more independent variables. Therefore, there is a multicollinearity problem, which can result in a relatively large standard error and reduce the power of my model to identify statistically significant variables.

# %%
## Correlation values Independent Variables vs. Target Variable
data2.corr().W.sort_values()
# Out:
# ERA   -0.826952
# RA    -0.823176
# ER    -0.815308
# 3B    -0.206737
# SB    -0.169503
# AB    -0.085780
# E     -0.072858
# H     -0.018360
# CG     0.029594
# SO     0.156469
# HR     0.245697
# 2B     0.384886
# R      0.390451
# BB     0.447513
# SHO    0.497526
# SV     0.749290
# W      1.000000
# Name: W, dtype: float64

# %% [markdown]
# ## Visualizing the correlation between label and features using bar plot

# %%
plt.figure(figsize=(10,4))
data2.corr()['W'].sort_values(ascending=False).drop(['W']).plot(kind='barh',color="m")
plt.xlabel('Feature',fontsize=15)
plt.xlabel('Target',fontsize=15)
plt.title("Correlation between label and features",fontsize=20)
plt.show()

# %% [markdown]
# In the graph above we can see the top features which are positively and negatively related to the target variable.

# %% [markdown]
# ## Skewness

# %%
# Checking for skewness

data2.skew()
# Out:
# W      0.119013
# R     -0.215364
# AB     0.169573
# H      0.783772
# 2B    -0.335304
# 3B     0.090124
# HR     0.450862
# BB     0.151193
# SO    -0.233815
# SB     0.494966
# RA     0.018155
# ER     0.018461
# ERA    0.016693
# CG     0.854980
# SHO    0.526943
# SV     0.627480
# E      0.840271
# dtype: float64

# %% [markdown]
# If we consider the range -0.5 to 0.5 for a symmetric distribution, there are some features, which are slightly out of this range with a moderately skewed distribution:
# - H,CG,SHO,SV,E.
#
# However, SV has a good correlation with target variable, so I will not remove skewness from this feature.

# %%
# Removing skewness using square-root, given that the features are moderately skewed.

#skd=data2.skew()
#skd=skd[abs(skd)>.5].index

#data2[skd]=np.log(data2[skd])

# %%
# Removing skewness using square-root, given that the skewness is positive and moderate.
data2['CG']=np.sqrt(data2['CG'])
data2['SHO']=np.sqrt(data2['SHO'])
data2['E']=np.sqrt(data2['E'])
data2['H']=np.sqrt(data2['H'])

# %%
data2.skew()
# Out:
# W      0.119013
# R     -0.215364
# AB     0.169573
# H      0.761274
# 2B    -0.335304
# 3B     0.090124
# HR     0.450862
# BB     0.151193
# SO    -0.233815
# SB     0.494966
# RA     0.018155
# ER     0.018461
# ERA    0.016693
# CG    -0.260678
# SHO   -0.085802
# SV     0.627480
# E      0.714966
# dtype: float64

# %% [markdown]
# We have removed skewness using the square-root method, given that the skewness is positive and moderate for these features.

# %%
# let us visualize the feature distribution after skewness removal

plt.figure(figsize=(20,25),facecolor='white')
plotnumber=1

for column in data2:
    if plotnumber<=13:
        ax=plt.subplot(4,4,plotnumber)
        sns.distplot(data2[column],color='m')
        plt.xlabel(column,fontsize=20)
    plotnumber+=1
plt.show()

# %% [markdown]
# The data in each feature looks normally distributed.

# %% [markdown]
# ## Separating features and label

# %%
# Separating the independent and target variables into x and y

x=data2.drop("W",axis=1)
y=data2["W"]

print("Feature Dimension",x.shape)
print("Label Dimension",y.shape)
# Out:
# Feature Dimension (29, 16)
# Label Dimension (29,)

# %% [markdown]
# ## Feature Scaling using Standard Scalarization

# %%
from sklearn.preprocessing import StandardScaler
scaler=StandardScaler()
x=pd.DataFrame(scaler.fit_transform(x),columns=x.columns)
x
# Out:
#            R        AB         H        2B        3B        HR        BB  \
# 0   0.959398  0.830084  1.731088  1.556538  1.010845 -0.765863 -1.536359
# 1   0.331147 -0.702831 -0.944305  0.201171  1.208917 -0.181389 -0.495021
# 2  -0.274666 -1.100253 -0.097707  1.733325 -0.276617 -0.697101  1.252941
# 3  -1.329231  0.233951 -0.353870 -0.800621 -0.474688 -0.869006 -1.145857
# 4   0.174084  1.255894  2.047274  0.908319  1.704094 -0.353293 -0.197495
# 5   1.856900  0.716535 -0.061217 -0.093474 -1.266972  1.743939  1.643442
# 6   0.712585 -0.447345 -0.556053 -1.625627 -1.167936  1.915843 -0.885522
# 7  -0.835605 -0.447345 -0.317196  0.260100  0.020490  0.196801 -0.550807
# 8   1.497899  1.752672  1.695839  1.202964  0.119526 -0.009484  0.230197
# 9   1.565212 -0.078310  0.338457  0.319029  0.020490  0.368705  0.695081
# 10  1.071586 -0.816380 -0.685137  0.260100 -0.573723  2.362794  0.378960
# 11 -0.454167 -1.412514 -1.279505 -1.802414 -1.068901  0.506228 -0.569402
# ...

# %% [markdown]
# ## Checking Variance Inflation Factor (VIF)

# %%
# Finding VIF in each scaled column

from statsmodels.stats.outliers_influence import variance_inflation_factor
vif=pd.DataFrame()
vif['VIF Values']=[variance_inflation_factor(x.values,i) for i in range(len(x.columns))]
vif["Features"]=x.columns

vif
# Out:
#      VIF Values Features
# 0      7.074633        R
# 1     17.122372       AB
# 2      9.427649        H
# 3      3.737370       2B
# 4      3.133608       3B
# 5      8.398294       HR
# 6      3.417599       BB
# 7      2.732229       SO
# 8      1.981172       SB
# 9    193.319759       RA
# 10  1787.380409       ER
# 11  1401.793986      ERA
# 12     2.882575       CG
# 13     3.304766      SHO
# 14     5.241594       SV
# 15     2.204905        E

# %% [markdown]
# VIF values, show that there are variables causing multicollinearity. In other words, there is a perfect correlation between pairs of independent variables. Therefore, I should try to drop those with low-variance.

# %% [markdown]
# ## Feature Engineering
# #### Feature Selection - Drop highly correlated features

# %%
# Get upper triangle of correlation matrix
upper = cor.where(np.triu(np.ones(cor.shape), k=1).astype(np.bool))

# %%
# Find features with correlation greater than 0.70
to_drop = [column for column in upper.columns if any(upper[column] > 0.70)]
to_drop
# Out:
# ['H', 'ER', 'ERA', 'SV']

# %% [markdown]
# According to this method, the features with a correlation greater than 0.70 are 'H', 'ER', 'ERA', 'SV'. I will drop them to avoid rendundancy. I've selected 0.70 as a threshold because higher values did not solve the multicollinearity issue, features remained moderately to highly correlated.

# %%
# Drop highly correlated features from dataset

x.drop(to_drop,axis=1,inplace=True)
x.shape
# Out:
# (29, 12)

# %%
# Again checking VIF value to confirm whether the multicollinearity still exists or not

vif=pd.DataFrame()
vif["VIF values"]=[variance_inflation_factor(x.values,i)
    for i in range(len(x.columns))]
vif["Features"]=x.columns
vif
# Out:
#     VIF values Features
# 0     4.450046        R
# 1     2.651649       AB
# 2     3.097725       2B
# 3     2.956246       3B
# 4     4.899562       HR
# 5     2.750763       BB
# 6     2.223233       SO
# 7     1.541002       SB
# 8     3.751087       RA
# 9     2.096776       CG
# 10    2.761944      SHO
# 11    1.431624        E

# %% [markdown]
# Now values are under 5, so we've corrected the critical levels of multicollinearity by dropping redundant features and; thus, keeping the most relevant ones for use in model construction.

# %% [markdown]
# ## Modelling

# %% [markdown]
# ### Finding the best random state

# %%
# importing necessary libraries
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import mean_squared_error
from sklearn.metrics import r2_score
from sklearn.ensemble import GradientBoostingRegressor
from sklearn.linear_model import LinearRegression

# %% [markdown]
# ### Creating train test split

# %%
maxAccu=0
maxRS=0

for i in range(1,200):
    x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.30,random_state=i)
    lr=LinearRegression()
    lr.fit(x_train,y_train)
    pred=lr.predict(x_test)
    acc=r2_score(y_test,pred)
    if acc>maxAccu:
        maxAccu=acc
        maxRS=i
print("Maximun r2 score is ",maxAccu, "on random_state",maxRS)
# Out:
# Maximun r2 score is  0.827678925153261 on random_state 50

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.30,random_state=maxRS)

# %%
# Shapes of the datasets
x_train.shape, x_test.shape, y_train.shape, y_test.shape
# Out:
# ((20, 12), (9, 12), (20,), (9,))

# %%
from sklearn.linear_model import LinearRegression
from sklearn.ensemble import RandomForestRegressor, ExtraTreesRegressor
from sklearn.tree import DecisionTreeRegressor
from sklearn.neighbors import KNeighborsRegressor as KNN
from sklearn.linear_model import Lasso, Ridge
from sklearn.svm import SVR

# %%
LR=LinearRegression()
LR.fit(x_train,y_train)
pred_LR=LR.predict(x_test)
pred_train=LR.predict(x_train)
LR_r=r2_score(y_test,pred_LR)
LR_rtd=r2_score(y_train, pred_train)
print('R2 Score:',LR_r)
print('R2 Score on training data:',LR_rtd)
print('Mean Absolute Error:',mean_absolute_error(y_test,pred_LR))
print('Mean Squared Error:',mean_squared_error(y_test,pred_LR))
print('Root Mean Squared Error:',np.sqrt(mean_squared_error(y_test,pred_LR)))
# Out:
# R2 Score: 0.827678925153261
# R2 Score on training data: 0.8084082382629556
# Mean Absolute Error: 4.114016237204442
# Mean Squared Error: 24.729137950845605
# Root Mean Squared Error: 4.972840028680352

# %%
plt.figure(figsize=(10,6))
plt.scatter(x=pred_LR,y=y_test,color='r')
plt.plot(pred_LR,pred_LR,color='b')
plt.xlabel("Actual",fontsize=14)
plt.ylabel("Predicted",fontsize=14)
plt.title("Linear Regression",fontsize=18)
plt.show()

# %%
RFR=RandomForestRegressor()
RFR.fit(x_train,y_train)
pred_RFR=RFR.predict(x_test)
pred_train=RFR.predict(x_train)
RFR_r=r2_score(y_test,pred_RFR)
RFR_rtd=r2_score(y_train, pred_train)
print('R2 Score:',RFR_r)
print('R2 Score on training data:',RFR_rtd)
print('Mean Absolute Error:',mean_absolute_error(y_test,pred_RFR))
print('Mean Squared Error:',mean_squared_error(y_test,pred_RFR))
print('Root Mean Squared Error:',np.sqrt(mean_squared_error(y_test,pred_RFR)))
# Out:
# R2 Score: 0.5261215846524432
# R2 Score on training data: 0.9065462866411772
# Mean Absolute Error: 6.847777777777777
# Mean Squared Error: 68.00447777777777
# Root Mean Squared Error: 8.246482751923862

# %%
plt.figure(figsize=(10,6))
plt.scatter(x=pred_RFR,y=y_test,color='r')
plt.plot(pred_RFR,pred_RFR,color='b')
plt.xlabel("Actual",fontsize=14)
plt.ylabel("Predicted",fontsize=14)
plt.title("RandomForestRegressor",fontsize=18)
plt.show()

# %%
knn=KNN()
knn.fit(x_train,y_train)
pred_knn=knn.predict(x_test)
pred_train=knn.predict(x_train)
knn_r=r2_score(y_test,pred_knn)
knn_rtd=r2_score(y_train, pred_train)
print('R2 Score:',knn_r)
print('R2 Score on training data:',knn_rtd)
print('Mean Absolute Error:',mean_absolute_error(y_test,pred_knn))
print('Mean Squared Error:',mean_squared_error(y_test,pred_knn))
print('Root Mean Squared Error:',np.sqrt(mean_squared_error(y_test,pred_knn)))
# Out:
# R2 Score: 0.4748967653131455
# R2 Score on training data: 0.3661221179469355
# Mean Absolute Error: 7.977777777777776
# Mean Squared Error: 75.35555555555551
# Root Mean Squared Error: 8.680757775422345

# %%
plt.figure(figsize=(10,6))
plt.scatter(x=pred_knn,y=y_test,color='r')
plt.plot(pred_knn,pred_knn,color='b')
plt.xlabel("Actual",fontsize=14)
plt.ylabel("Predicted",fontsize=14)
plt.title("KNN",fontsize=18)
plt.show()

# %%
GBR=GradientBoostingRegressor()
GBR.fit(x_train,y_train)
pred_GBR=GBR.predict(x_test)
pred_train=GBR.predict(x_train)
GBR_r=r2_score(y_test,pred_GBR)
GBR_rtd=r2_score(y_train, pred_train)
print('R2 Score:',GBR_r)
print('R2 Score on training data:',GBR_rtd)
print('Mean Absolute Error:',mean_absolute_error(y_test,pred_GBR))
print('Mean Squared Error:',mean_squared_error(y_test,pred_GBR))
print('Root Mean Squared Error:',np.sqrt(mean_squared_error(y_test,pred_GBR)))
# Out:
# R2 Score: 0.3300448414141235
# R2 Score on training data: 0.9999997676349178
# Mean Absolute Error: 8.514153328816574
# Mean Squared Error: 96.14270078274356
# Root Mean Squared Error: 9.805238435792551

# %%
plt.figure(figsize=(10,6))
plt.scatter(x=pred_GBR,y=y_test,color='r')
plt.plot(pred_GBR,pred_GBR,color='b')
plt.xlabel("Actual",fontsize=14)
plt.ylabel("Predicted",fontsize=14)
plt.title("GradientBoostingRegressor",fontsize=18)
plt.show()

# %%
lasso=Lasso()
lasso.fit(x_train,y_train)
pred_lasso=lasso.predict(x_test)
pred_train=lasso.predict(x_train)
lasso_r=r2_score(y_test,pred_lasso)
lasso_rtd=r2_score(y_train, pred_train)
print('R2 Score:',lasso_r)
print('R2 Score on training data:',lasso_rtd)
print('Mean Absolute Error:',mean_absolute_error(y_test,pred_lasso))
print('Mean Squared Error:',mean_squared_error(y_test,pred_lasso))
print('Root Mean Squared Error:',np.sqrt(mean_squared_error(y_test,pred_lasso)))
# Out:
# R2 Score: 0.811039448050975
# R2 Score on training data: 0.7407545730270828
# Mean Absolute Error: 4.456702788350161
# Mean Squared Error: 27.117005627845266
# Root Mean Squared Error: 5.207399123155941

# %%
plt.figure(figsize=(10,6))
plt.scatter(x=pred_lasso,y=y_test,color='r')
plt.plot(pred_lasso,pred_lasso,color='b')
plt.xlabel("Actual",fontsize=14)
plt.ylabel("Predicted",fontsize=14)
plt.title("Lasso",fontsize=18)
plt.show()

# %%
rd=Ridge()
rd.fit(x_train,y_train)
pred_ridge=rd.predict(x_test)
pred_train=rd.predict(x_train)
ridge_r=r2_score(y_test,pred_ridge)
ridge_rtd=r2_score(y_train, pred_train)
print('R2 Score:',ridge_r)
print('R2 Score on training data:',ridge_rtd)
print('Mean Absolute Error:',mean_absolute_error(y_test,pred_ridge))
print('Mean Squared Error:',mean_squared_error(y_test,pred_ridge))
print('Root Mean Squared Error:',np.sqrt(mean_squared_error(y_test,pred_ridge)))
# Out:
# R2 Score: 0.8269749010865527
# R2 Score on training data: 0.8005123903795166
# Mean Absolute Error: 4.210470422709586
# Mean Squared Error: 24.830169750245823
# Root Mean Squared Error: 4.982988034326977

# %%
plt.figure(figsize=(10,6))
plt.scatter(x=pred_ridge,y=y_test,color='r')
plt.plot(pred_ridge,pred_ridge,color='b')
plt.xlabel("Actual",fontsize=14)
plt.ylabel("Predicted",fontsize=14)
plt.title("Ridge",fontsize=18)
plt.show()

# %%
dtr=DecisionTreeRegressor()
dtr.fit(x_train,y_train)
pred_DTR=dtr.predict(x_test)
pred_train=dtr.predict(x_train)
dtr_r=r2_score(y_test,pred_DTR)
dtr_rtd=r2_score(y_train, pred_train)
print('R2 Score:',dtr_r)
print('R2 Score on training data:',dtr_rtd)
print('Mean Absolute Error:',mean_absolute_error(y_test,pred_DTR))
print('Mean Squared Error:',mean_squared_error(y_test,pred_DTR))
print('Root Mean Squared Error:',np.sqrt(mean_squared_error(y_test,pred_DTR)))
# Out:
# R2 Score: 0.2381280110116999
# R2 Score on training data: 1.0
# Mean Absolute Error: 9.11111111111111
# Mean Squared Error: 109.33333333333333
# Root Mean Squared Error: 10.456258094238748

# %%
plt.figure(figsize=(10,6))
plt.scatter(x=pred_DTR,y=y_test,color='r')
plt.plot(pred_DTR,pred_DTR,color='b')
plt.xlabel("Actual",fontsize=14)
plt.ylabel("Predicted",fontsize=14)
plt.title("Decision Tree Regressor",fontsize=18)
plt.show()

# %%
svr=SVR()
svr.fit(x_train,y_train)
pred_SVR=svr.predict(x_test)
pred_train=svr.predict(x_train)
svr_r=r2_score(y_test,pred_SVR)
svr_rtd=r2_score(y_train, pred_train)
print('R2 Score:',svr_r)
print('R2 Score on training data:',svr_rtd)
print('Mean Absolute Error:',mean_absolute_error(y_test,pred_SVR))
print('Mean Squared Error:',mean_squared_error(y_test,pred_SVR))
print('Root Mean Squared Error:',np.sqrt(mean_squared_error(y_test,pred_SVR)))
# Out:
# R2 Score: 0.10765397841465929
# R2 Score on training data: 0.17338435370926064
# Mean Absolute Error: 10.25499139754367
# Mean Squared Error: 128.0571624062716
# Root Mean Squared Error: 11.316234462323216

# %%
plt.figure(figsize=(10,6))
plt.scatter(x=pred_SVR,y=y_test,color='r')
plt.plot(pred_SVR,pred_SVR,color='b')
plt.xlabel("Actual",fontsize=14)
plt.ylabel("Predicted",fontsize=14)
plt.title("SVR",fontsize=18)
plt.show()

# %%
etr=ExtraTreesRegressor()
etr.fit(x_train,y_train)
pred_ETR=etr.predict(x_test)
pred_train=etr.predict(x_train)
etr_r=r2_score(y_test,pred_ETR)
etr_rtd=r2_score(y_train, pred_train)

print('R2 Score:',etr_r)
print('R2 Score on training data:',etr_rtd)
print('Mean Absolute Error:',mean_absolute_error(y_test,pred_ETR))
print('Mean Squared Error:',mean_squared_error(y_test,pred_ETR))
print('Root Mean Squared Error:',np.sqrt(mean_squared_error(y_test,pred_ETR)))
# Out:
# R2 Score: 0.5685446920165176
# R2 Score on training data: 1.0
# Mean Absolute Error: 6.376666666666665
# Mean Squared Error: 61.91649999999999
# Root Mean Squared Error: 7.868703832271233

# %%
plt.figure(figsize=(10,6))
plt.scatter(x=pred_ETR,y=y_test,color='r')
plt.plot(pred_ETR,pred_ETR,color='b')
plt.xlabel("Actual",fontsize=14)
plt.ylabel("Predicted",fontsize=14)
plt.title("Extra Trees Regressor",fontsize=18)
plt.show()

# %%
# Checking all algorithm results

results_alg=pd.DataFrame({'Model':['LinearRegression','RandomForestRegressor','KNeighborsRegressor','GradientBoostingRegressor',
'Lasso','Ridge','DecisionTreeRegressor','SVR','ExtraTreesRegressor'],'R2 Score':[LR_r,RFR_r,knn_r,GBR_r,lasso_r,ridge_r,dtr_r,svr_r,etr_r],'R2 Score on Training Data':[LR_rtd,RFR_rtd,knn_rtd,GBR_rtd,lasso_rtd,ridge_rtd,dtr_rtd,svr_rtd,etr_rtd]})
results_alg.index+=1
results_alg
# Out:
#                        Model  R2 Score  R2 Score on Training Data
# 1           LinearRegression  0.827679                   0.808408
# 2      RandomForestRegressor  0.526122                   0.906546
# 3        KNeighborsRegressor  0.474897                   0.366122
# 4  GradientBoostingRegressor  0.330045                   1.000000
# 5                      Lasso  0.811039                   0.740755
# 6                      Ridge  0.826975                   0.800512
# 7      DecisionTreeRegressor  0.238128                   1.000000
# 8                        SVR  0.107654                   0.173384
# 9        ExtraTreesRegressor  0.568545                   1.000000

# %% [markdown]
# The following models do not generalize well: RandomForestRegressor, GradientBoostingRegressor, DecisionTreeRegressor and ExtraTreesRegressor. This is evident by training scores considerably greater than the testing scores, indicating; therefore, overfitting of the model towards the training data.
#
# Others, like KNeighborsRegressor and SVR have a poor prediction performance on both test and training datasets.
#
# The models with the best prediction performance are LinearRegression, LASSO and Ridge. Here, the training  scores are worse  or close  to  the  testing  scores, indicating no overfitting and good generalization capabilities.

# %% [markdown]
# ## Cross Validation Score

# %%
from sklearn.model_selection import cross_val_score

# %%
# Checking CV Score
score=cross_val_score(LR,x,y,cv=7,scoring="r2")
print(score)
print(score.mean())
print("Difference between R2 Score and Cross Validation Score is",(r2_score(y_test,pred_LR)-score.mean())*100)
# Out:
# [ 0.15014994 -0.05746241 -1.67561708 -0.01779716  0.49141324  0.76854562
#   0.35630755]
# 0.0022199587323792347
# Difference between R2 Score and Cross Validation Score is 82.54589664208818

# %%
# Checking CV Score
score1=cross_val_score(RFR,x,y)
print(score1)
print(score1.mean())
print("Difference between R2 Score and Cross Validation Score is",(r2_score(y_test,pred_RFR)-score1.mean())*100)
# Out:
# [ 0.05252091 -3.76949474  0.27239724  0.10709098  0.70723821]
# -0.5260494793897577
# Difference between R2 Score and Cross Validation Score is 105.21710640422009

# %%
# Checking CV Score
score2=cross_val_score(knn,x,y)
print(score2)
print(score2.mean())
print("Difference between R2 Score and Cross Validation Score is",(r2_score(y_test,pred_knn)-score2.mean())*100)
# Out:
# [-0.28768182 -1.56631579  0.24965286  0.1837377   0.77488208]
# -0.12914499247113792
# Difference between R2 Score and Cross Validation Score is 60.40417577842834

# %%
# Checking CV Score
score3=cross_val_score(GBR,x,y)
print(score3)
print(score3.mean())
print("Difference between R2 Score and Cross Validation Score is",(r2_score(y_test,pred_GBR)-score3.mean())*100)
# Out:
# [-0.17728842 -8.60713076  0.3597354   0.20141818  0.51582035]
# -1.5414890514623223
# Difference between R2 Score and Cross Validation Score is 187.1533892876446

# %%
# Checking CV Score
score4=cross_val_score(lasso,x,y)
print(score4)
print(score4.mean())
print("Difference between R2 Score and Cross Validation Score is",(r2_score(y_test,pred_lasso)-score4.mean())*100)
# Out:
# [ 0.49290202 -0.83656416  0.60067191  0.66366341  0.90493262]
# 0.3651211610136135
# Difference between R2 Score and Cross Validation Score is 44.591828703736155

# %%
# Checking CV Score
score5=cross_val_score(rd,x,y)
print(score5)
print(score5.mean())
print("Difference between R2 Score and Cross Validation Score is",(r2_score(y_test,pred_ridge)-score5.mean())*100)
# Out:
# [ 0.1282999  -1.94692265  0.44409669  0.761979    0.8022835 ]
# 0.03794728815084656
# Difference between R2 Score and Cross Validation Score is 78.9027612935706

# %%
# Checking CV Score
score6=cross_val_score(dtr,x,y)
print(score6)
print(score6.mean())
print("Difference between R2 Score and Cross Validation Score is",(r2_score(y_test,pred_DTR)-score6.mean())*100)
# Out:
# [ -2.60340909 -12.13157895   0.16771225   0.15081967  -0.04363208]
# -2.892017637466231
# Difference between R2 Score and Cross Validation Score is 313.01456484779305

# %%
# Checking CV Score
score7=cross_val_score(svr,x,y)
print(score7)
print(score7.mean())
print("Difference between R2 Score and Cross Validation Score is",(r2_score(y_test,pred_SVR)-score7.mean())*100)
# Out:
# [-0.10405823 -1.2174474  -0.00889101 -0.45844067  0.17024676]
# -0.32371810974236526
# Difference between R2 Score and Cross Validation Score is 43.13720881570246

# %%
# Checking CV Score
score8=cross_val_score(etr,x,y)
print(score8)
print(score8.mean())
print("Difference between R2 Score and Cross Validation Score is",(r2_score(y_test,pred_ETR)-score8.mean())*100)
# Out:
# [-0.54604659 -3.66927237  0.42303789  0.05763443  0.61059375]
# -0.6248105782010551
# Difference between R2 Score and Cross Validation Score is 119.33552702175727

# %% [markdown]
# As per model performance analysis and cross validation scores, LASSO, seems to be the best model.

# %% [markdown]
# ## Hyperparameter Tuning

# %%
# To increase the performance of the model
# Lasso
import random
from sklearn.model_selection import GridSearchCV

# Always take at least 5 parameters
parameters={'alpha':[0.005, 0.02, 0.03, 0.05, 0.06],'selection':['cyclic','random'],'max_iter':[1000,1250,1500,2000],'random_state':[10,35,40,42,87,478,900]}

# %%
gscv=GridSearchCV(Lasso(),parameters,cv=5)

# %%
gscv.fit(x_train,y_train)
# Out:
# GridSearchCV(cv=5, estimator=Lasso(),
#              param_grid={'alpha': [0.005, 0.02, 0.03, 0.05, 0.06],
#                          'max_iter': [1000, 1250, 1500, 2000],
#                          'random_state': [10, 35, 40, 42, 87, 478, 900],
#                          'selection': ['cyclic', 'random']})

# %%
gscv.best_params_
# Out:
# {'alpha': 0.06, 'max_iter': 1000, 'random_state': 478, 'selection': 'random'}

# %%
Lasso().get_params().keys()
# Out:
# dict_keys(['alpha', 'copy_X', 'fit_intercept', 'max_iter', 'positive', 'precompute', 'random_state', 'selection', 'tol', 'warm_start'])

# %%
Model=Lasso(alpha=0.06,max_iter=1000,random_state=478,selection='random')

# %%
Model.fit(x_train,y_train)
pred=Model.predict(x_test)
print('R2 Score:',r2_score(y_test,pred))
print('Mean Absolute Error:',mean_absolute_error(y_test,pred))
print('Mean Squared Error:',mean_squared_error(y_test,pred))
print('Root Mean Squared Error:',np.sqrt(mean_squared_error(y_test,pred)))
# Out:
# R2 Score: 0.8497291361438274
# Mean Absolute Error: 3.8003191968960914
# Mean Squared Error: 21.564796561285803
# Root Mean Squared Error: 4.643791184074258

# %% [markdown]
# After hyperparameter tuning, the performance of the model has improved from 81.10% to 84.97% and errors have decreased.

# %% [markdown]
# ## Saving the Model

# %%
# Saving the model using .pkl
import pickle
filename="BaseballCaseStudy.pkl"
pickle.dump(Model,open(filename,'wb'))

# %%
import pickle
loaded_model=pickle.load(open("BaseballCaseStudy.pkl","rb"))
result=loaded_model.score(x_test,y_test)
print(result*100)
# Out:
# 84.97291361438273

# %% [markdown]
# ## Get Predictions - Number of predicted wins (W)

# %%
conclusion=pd.DataFrame([loaded_model.predict(x_test)[:],y_test[:]],index=['Predicted','Original'])
conclusion
# Out:
#                    0          1          2          3         4          5  \
# Predicted  68.454608  80.672839  74.720219  80.187488  75.33759  66.955243
# Original   68.000000  78.000000  74.000000  88.000000  68.00000  64.000000
#
#                    6          7           8
# Predicted  85.346573  91.641377   96.044942
# Original   92.000000  90.000000  100.000000

# %%
The results of the model are close to original data.
